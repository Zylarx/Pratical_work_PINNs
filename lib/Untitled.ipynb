# %%
# %load_ext autoreload
# %autoreload 2 
# %reload_ext autoreload
# %matplotlib widget


import decoder 
import torch 
import matplotlib.pyplot as plt 
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
gen = decoder.decoder(64, "cpu")

# %%
data = torch.zeros(1,1,3)*1.5

data[:,:,0] = 0.3
data[:,:,1] = np.deg2rad(45)
data[:,:,2] = np.deg2rad(9)

# %%
gen_img = gen(data)
# Out:
# torch.Size([1, 100, 4])

# %%
plt.figure()
plt.imshow(gen_img.reshape(64,64))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
